# %%
#imports
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ### 1. Euclidean plane

# %% [markdown]
# Consider this 3 points on 2D space:
# $A=(4, 5)$
# $B=(-2, -4)$
# $C=(8, -1)$

# %% [markdown]
# #### 1.1. Plot them using `matplotlib`

# %%
𝐴 = (4,5)
B = (-2,-4)
C = (8,-1)

# %%
# create a plot
fig, ax = plt.subplots()

# add points. "o" stands for circle, "*" would be a star point
plt.plot(A[0], A[1], "o", markersize=10, label="A")
plt.plot(B[0], B[1], "o", markersize=10, label="B")
plt.plot(C[0], C[1], "o", markersize=10, label="C")

# set axis limits
ax.set_xlim([-6, 10])
ax.set_ylim([-6, 10])
# this adds top right legend for labeled elements
plt.legend()

# %% [markdown]
# #### 1.2. Which distance is longer, $AC, AB, \text{or} BC$? Write a function that calculates distance between two points.

# %%
# hipotenusa
ax.plot((A[0], B[0]), (A[1], B[1]), "black")

# catetos
ax.plot((A[0], A[0]), (A[1], B[1]), "black")
ax.plot((A[0], B[0]), (B[1], B[1]), "black")

fig

# %%
# vertical segment 
c1 = A[1] - B[1]
# horizontal segment
c2 = A[0] - B[0]

dist_AB = math.sqrt(c1 ** 2 + c2 ** 2)

# %%
dist_AB
# Out:
# 10.816653826391969

# %%
# hipotenusa
ax.plot((B[0], C[0]), (B[1], C[1]), "black")

# catetos
ax.plot((B[0], B[0]), (B[1], C[1]), "black")
ax.plot((B[0], C[0]), (C[1], C[1]), "black")

fig

# %%
# vertical segment 
c1 = B[1] - C[1]
# horizontal segment
c2 = B[0] - C[0]

dist_BC = math.sqrt(c1 ** 2 + c2 ** 2)

# %%
dist_BC
# Out:
# 10.44030650891055

# %%
# hipotenusa
ax.plot((A[0], C[0]), (A[1], C[1]), "black")

# catetos
ax.plot((A[0], A[0]), (A[1], C[1]), "black")
ax.plot((A[0], C[0]), (C[1], C[1]), "black")

fig

# %%
# vertical segment 
c1 = A[1] - C[1]
# horizontal segment
c2 = A[0] - C[0]

dist_AC = math.sqrt(c1 ** 2 + c2 ** 2)

# %%
dist_AC
# Out:
# 7.211102550927978

# %% [markdown]
# #### La mayor de las 3 hipotenusas es la de los puntos AB
# #### --------------------------------------------------------------

# %% [markdown]
# #### 1.3. What is the perimeter of triangle $ABC$?

# %%
𝐴 = (4,5)
B = (-2,-4)
C = (8,-1)

# %%
# create a plot
fig, ax = plt.subplots()

# add points. "o" stands for circle, "*" would be a star point
plt.plot(A[0], A[1], "o", markersize=10, label="A")
plt.plot(B[0], B[1], "o", markersize=10, label="B")
plt.plot(C[0], C[1], "o", markersize=10, label="C")

# set axis limits
ax.set_xlim([-6, 10])
ax.set_ylim([-6, 10])
# this adds top right legend for labeled elements
plt.legend()

# hipotenusa
ax.plot((A[0], B[0]), (A[1], B[1]), "black")
ax.plot((A[0], C[0]), (A[1], C[1]), "black")
ax.plot((B[0], C[0]), (B[1], C[1]), "black")

fig

# %%
perimetro = dist_AB + dist_AC + dist_BC

# %%
perimetro
# Out:
# 28.4680628862305

# %% [markdown]
# ### 2. Linear functions

# %% [markdown]
# Consider the following straight lines on 2D space:
# $y_1=2x-3$
# $y_2=-3x+12$

# %% [markdown]
# #### 2.1. Plot them

# %%
def create_basicplot():
    fig, ax = plt.subplots(figsize = (10,10))
    
    # where do we want lines
    ticks = np.arange(-100, 100,1)
    
    # draw grid
    ax.set_xticks(ticks)
    ax.set_yticks(ticks)
    ax.grid(True, which='both')
    
    # 1-1 X and Y proportion
    ax.set_aspect('equal')
    
    # X and Y axes
    ax.axhline(y=0, color='b')
    ax.axvline(x=0, color='b')
    
       
    # set axes' limits
    ax.set_xlim([-15, 15])
    ax.set_ylim([-15, 15])

# %%
import numpy as np

x = np.linspace(
    start=-10, 
    stop=10, 
    num=300
)

# %%
y1 = 2 * x - 3
y2 = -3 * x + 12

# %%
create_basicplot()

plt.plot(x, y1, "-", markersize=10, label="2x-3")
plt.plot(x, y2, "-", markersize=10, label="-3x+12")

plt.legend()

# %% [markdown]
# #### 2.2. What are the respective slopes

# %% [markdown]
# #### 2.3. Give 3 points through which $y_1$ goes through

# %%
y1 = 2*x - 3

𝐴 = (0,-3)
B = (1,-1)
C = (2,1)

# %% [markdown]
# #### 2.4. Where do they intersect?

# %%
# en el punto (3,3)

# %% [markdown]
# #### 2.5. BONUS

# %% [markdown]
# My yearly salary has increased **linearly** with my age:
# When I was 21 years old, I did 10000\\$ / year
# Today I am 39 years old, I am doing 33400\\$ / year
# How much will I do when I get 50 years old?

# %%
edad1 = 21
edad2 = 39
edad3 = 50
sueldo1 = 10000
sueldo2 = 33400
sueldo3 = 0

calc1 = edad2 - edad1
calc1a = edad3 - edad2
calc2 = (sueldo1*100)/sueldo2
calc2 = 100-calc2

calc3 = (calc2*calc1a)/calc1
calc4 = (calc3*sueldo2)/100

calc5 = sueldo2 + calc4

# %%
calc5
# Out:
# 47700.0

# %% [markdown]
# ### 3. Polynomials

# %% [markdown]
# Consider these different degree polynomials:
# $y_2=x^2-3x-10$
# $y_3=x^3-2x^2+5x+1$
# $y_4=x^4-x^3+x^2-x+1$

# %%
y2 = (x**2) - (3 * x) - 10
y3 = (x**3) - (5 *(x**2)) + 1
y4 = (x**4) - (x**3) + (x**2) + 1

# %% [markdown]
# #### 3.1. Plot them

# %%
create_basicplot()

plt.plot(x, y2, "-", markersize=10, label="x2−3x−10 ")
plt.plot(x, y3, "-", markersize=10, label="x3−2x2+5x+1")
plt.plot(x, y4, "-", markersize=10, label="x4−x3+x2−x+1")

plt.legend()

# %% [markdown]
# #### 3.2. Which one takes a bigger value on $x=0$? On $x=2$? On $x=100$?

# %%
x=0
y2 = (x**2) - (3 * x) - 10
y3 = (x**3) - (5 *(x**2)) + 1
y4 = (x**4) - (x**3) + (x**2) + 1
print (f"{y2, y3, y4}"" el valor mas alto es:"f"{y4}")
# Out:
# (-10, 1, 1) el valor mas alto es:1

# %%
x=2
y2 = (x**2) - (3 * x) - 10
y3 = (x**3) - (5 *(x**2)) + 1
y4 = (x**4) - (x**3) + (x**2) + 1
print (y2, y3, y4)
# Out:
# -12 -11 13

# %%
x=100
y2 = (x**2) - (3 * x) - 10
y3 = (x**3) - (5 *(x**2)) + 1
y4 = (x**4) - (x**3) + (x**2) + 1
print (y2, y3, y4)
# Out:
# 9690 950001 99010001

# %% [markdown]
# #### 3.3. Who is the vertex of parabola $y_2$?

# %%
y2 = (x**2) - (3 * x) - 10

# %%
a = 1
b = -3
c = -10

def parabola(a, b, c):
    print ("Vertice: (" , (-b / (2 * a)) , ", " ,(((4 * a * c) - (b * b)) / (4 * a)) , ")" )
  
parabola(a, b, c)
# Out:
# Vertice: ( 1.5 ,  -12.25 )

# %% [markdown]
# #### 3.4. Where does $y_2$ intersect X axis? And Y axis?

# %%
a = 1
b = -3
c = -10

def parabola(a, b, c):
    print ("Directrix: y=" , (int)(c - ((b * b) + 1) * 4 * a ))

parabola(a, b, c)
# Out:
# Directrix: y= -50

# %% [markdown]
# #### 3.5. As x gets very big, what happens to $y$ go in each case?

# %%
# eje x
# y=0
# y2 = (x**2) - (3 * x) - 10
# y3= (x+2)*(x-5)
# o x+2 = 0 y x-5=

# la interseccion son (-2,0) y (5,0)

# eje y
# x=0
# y2 = (x**2) - (3 * x) - 10
print(y3)
# Out:
# -10

# %% [markdown]
# #### 3.6. As x gets very small (big negative), what happens to $y$ go in each case?

# %% [markdown]
# ### 4. Exponential

# %% [markdown]
# #### 4.1. Print number $e$ rounded to 3 decimal figures

# %% [markdown]
# #### 4.2. Compute $e$ to the powers 0, 1, 2, 3, 10

# %% [markdown]
# #### 4.3. Compute $e$ to the powers 0, -1, -2, -3, -10

# %% [markdown]
# #### 4.4. Plot functions $e^x$, $e^{2x}$, $e^{-x}$

# %% [markdown]
# Note: choose an appropiate x-range to visualize them all toguether

# %% [markdown]
# ### 5. Sum notation

# %% [markdown]
# Find the following:

# %% [markdown]
# $$\sum_{n=4}^7 n$$

# %% [markdown]
# $$\sum_{n=-2}^3 (n + 1)$$

# %% [markdown]
# $$\sum_{n=-2}^3 (n^2 - 2)$$

# %% [markdown]
# $$\sum_{n=0}^4 (10^n - 1)$$

# %% [markdown]
# ### 6. Combinatorics

# %% [markdown]
# #### 6.1. Ten people go to a party. How many handshakes happen?

# %% [markdown]
# #### 6.2. My family is composed of 11 members. By christmas, one buys food, one cooks and one cleans. How many possible arrangements of buyer-cooker-cleaner are there?

# %% [markdown]
# ### BONUS

# %% [markdown]
# 11 and 13 are twin primes, since:
#  - they are both primes
#  - their distance is 2
#
# Find all pairs of twin primes below 1000
